# %%
import requests
import pandas as pd
from dotenv import load_dotenv  # for loading environment variables
import os
from functions import fetch_movie_data, extract_awards_info, compute_aggregated_score, scrape_gross

load_dotenv()
api_key = os.getenv("API_KEY")

# %%
df = pd.read_csv("imdb_movies.csv")

# %%
df.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
#
#                     orig_title     status            orig_lang     budget_x  \
# 0                    Creed III   Released              English   75000000.0
# 1     Avatar: The Way of Water   Released              English  460000000.0
# 2  The Super Mario Bros. Movie   Released              English  100000000.0
# 3                       Momias   Released   Spanish, Castilian   12300000.0
# 4                    Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US

# %%
df["genre"].isna().sum()
# Out:
# 85

# %%
# Display rows where the 'Title' column contains a null value
null_rows_title = df[df['genre'].isnull()]

# Display the rows with null values in 'Title' column
print(null_rows_title)
# Out:
#                                        names       date_x  score genre  \
# 305         Housewife Sex Slaves: Hatano Yui  01/09/2015     0.0   NaN
# 1174                 Beauty Rope Cosmetology  12/02/1983    10.0   NaN
# 1561                                 Reclaim  07/29/2022    20.0   NaN
# 1762              Ancient Chinese Whorehouse  09/15/1994    50.0   NaN
# 1776       Porno document: Toruko tokkyû bin  02/26/1982   100.0   NaN
# ...                                      ...          ...    ...   ...
# 9626                                Euphoria  11/29/2022     0.0   NaN
# 9733                                 Fanatic  04/06/2023     0.0   NaN
# 10011                        Perfumed Garden  06/03/2000    53.0   NaN
# 10025  The Girl and the Wooden Horse Torture  12/03/1982    50.0   NaN
# 10076      The Shoga (Glass and Gas) Company  09/07/1990    37.0   NaN
#
#                                                 overview  \
# 305    We don't have an overview translated in Englis...
# 1174   Miki is the daughter of an affluent family. Sh...
# 1561   She is a good woman living a fulfilling life. ...
# 1762   Madam Five and carpenter Kong work together ma...
# 1776                                    Pinku from 1982.
# ...                                                  ...
# 9626   Artist and filmmaker Julian Rosefeldt creates ...
# 9733   Charlie and Gerald reunite their failed 2000's...
# 10011  Imagine a world of pleasure, where passion is ...
# 10025  Nami is a masochistic high school student who ...
# 10076  "I have not been very active as a social filmm...
#
#                                                     crew  \
# 305                                         Yui Hatano,
# 1174   Miki Takakura, Miki, Maya Ito, Rena, Ren Osugi...
# 1561                                                 NaN
# 1762   Kent Cheng, Kong, Yvonne Yung Hung, Miss Ng, S...
# 1776   Jun Miho, , Rumi Kagawa, , Miyuki Oka, , Kayok...
# ...                                                  ...
# 9626   Giancarlo Esposito, Taxi Driver, Virginia Newc...
# 9733   Matt Cook, , Caroline Rhea, , Shannon Dang, , ...
# 10011  Ivan Baccarat, Michael, Amy Lindsay, Lisa, Raj...
# 10025  Serina Nishikawa, Nami Tsuchiya, Waka Oda, , A...
# 10076                                                NaN
#
#                       orig_title     status   orig_lang     budget_x  \
# 305                  人妻性奴隷 波多野結衣   Released    Japanese  167540000.0
# 1174                   団鬼六　美女縄化粧   Released    Japanese  201940000.0
# 1561                     Reclaim   Released     Chinese   12001040.0
# 1762                       青樓十二房   Released   Cantonese  163600000.0
# 1776            ポルノドキュメント　トルコ特急便   Released    Japanese  201000000.0
# ...                          ...        ...         ...          ...
# 9626                    Euphoria   Released     English  167540000.0
# 9733                     Fanatic   Released     English  167540000.0
# 10011            Perfumed Garden   Released     English  159000000.0
# 10025                 団鬼六　少女木馬責め   Released    Japanese  163600000.0
# 10076   Sherkat-e Shisheh va Gaz   Released     Persian   58670000.0
#
#             revenue country
# 305    1.752700e+08      JP
# 1174   3.815731e+07      JP
# 1561   3.813901e+07      US
# 1762   8.126672e+08      HK
# 1776   1.569324e+09      JP
# ...             ...     ...
# 9626   1.752700e+08      US
# 9733   1.752700e+08      US
# 10011  2.792784e+08      ID
# 10025  8.126672e+08      JP
# 10076  3.859605e+08      IR
#
# [85 rows x 12 columns]

# %%
df_copy = df[["names", "orig_lang", "budget_x", "revenue"]]
df_copy
# Out:
#                                          names            orig_lang  \
# 0                                    Creed III              English
# 1                     Avatar: The Way of Water              English
# 2                  The Super Mario Bros. Movie              English
# 3                                      Mummies   Spanish, Castilian
# 4                                    Supercell              English
# ...                                        ...                  ...
# 10173                       20th Century Women              English
# 10174  Delta Force 2: The Colombian Connection              English
# 10175                         The Russia House              English
# 10176         Darkman II: The Return of Durant              English
# 10177       The Swan Princess: A Royal Wedding              English
#
#           budget_x       revenue
# 0       75000000.0  2.716167e+08
# 1      460000000.0  2.316795e+09
# 2      100000000.0  7.244590e+08
# 3       12300000.0  3.420000e+07
# 4       77000000.0  3.409420e+08
# ...            ...           ...
# 10173    7000000.0  9.353729e+06
# 10174    9145817.8  6.698361e+06
# 10175   21800000.0  2.299799e+07
# 10176  116000000.0  4.756613e+08
# 10177   92400000.0  5.394018e+08
#
# [10178 rows x 4 columns]

# %%
# Convert the 'date_x' column to datetime format if it's not already in datetime
df_copy['date_x'] = pd.to_datetime(df['date_x'])

# Filter rows where the year is between 1995 and 2020 (inclusive)
df_copy = df_copy[(df_copy['date_x'].dt.year >= 1995)]

# Display the filtered dataframe
print(df_copy.value_counts())
# Out:
# names                               orig_lang   budget_x     revenue      date_x
# #Alive                              Korean      6300000.0    13416285.0   2020-06-24    1
# Shazam! Fury of the Gods            English     125000000.0  132107025.0  2023-03-16    1
# Shiloh                              English     44400000.0   371501189.4  1996-11-30    1
# Sherlock: The Abominable Bride      English     120800000.0  810491789.2  2016-01-05    1
# Sherlock Holmes: A Game of Shadows  English     125000000.0  535663443.0  2012-01-05    1
#                                                                                        ..
# Haywire                             English     23000000.0   36374700.0   2012-03-14    1
# Hawa                                French      51600000.0   249812559.2  2022-12-09    1
# Havoc                               English     9000000.0    4176154.6    2005-10-16    1
# Have a Nice Day!                    Portuguese  103040000.0  412503777.6  2023-03-10    1
# 솔라 플라워                              Korean      181600000.0  175269998.8  2023-04-06    1
# Name: count, Length: 8497, dtype: int64
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\2947935964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['date_x'] = pd.to_datetime(df['date_x'])

# %%
# Rename the 'names' column to 'Title'
df_copy.rename(columns={'names': 'Title'}, inplace=True)
df_copy.head()
# Out:
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\4086769478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.rename(columns={'names': 'Title'}, inplace=True)
#                          Title            orig_lang     budget_x  \
# 0                    Creed III              English   75000000.0
# 1     Avatar: The Way of Water              English  460000000.0
# 2  The Super Mario Bros. Movie              English  100000000.0
# 3                      Mummies   Spanish, Castilian   12300000.0
# 4                    Supercell              English   77000000.0
#
#         revenue     date_x
# 0  2.716167e+08 2023-03-02
# 1  2.316795e+09 2022-12-15
# 2  7.244590e+08 2023-04-05
# 3  3.420000e+07 2023-01-05
# 4  3.409420e+08 2023-03-17

# %%
df_copy = df_copy.drop_duplicates(subset=['Title']) #Ben add

# %%
api_data_list = []
for title in df_copy['Title'].unique():  # Avoid repeated API calls for the same title
    movie_data = fetch_movie_data(title)
    if movie_data and movie_data.get('Response') == 'True':  # Only append valid data
        api_data_list.append(movie_data)

# %%
# Create a DataFrame from the list of API data
df_api = pd.DataFrame(api_data_list, columns=["Title", "Year", "Rated", "Runtime", "Genre", "Director", "Actors", "Plot", "Country", "Awards", "Metascore", "imdbRating", "imdbVotes", "imdbID"])
df_api
# Out:
#                                             Title  Year  Rated  Runtime  \
# 0                                       Creed III  2023  PG-13  116 min
# 1                        Avatar: The Way of Water  2022  PG-13  192 min
# 2                     The Super Mario Bros. Movie  2023     PG   92 min
# 3                                         Mummies  2023     PG   88 min
# 4                                       Supercell  2023  PG-13  100 min
# ...                                           ...   ...    ...      ...
# 7573                                The Love Guru  2008  PG-13   87 min
# 7574  The Seven Deadly Sins: Prisoners of the Sky  2018  TV-14   99 min
# 7575                           20th Century Women  2016      R  119 min
# 7576             Darkman II: The Return of Durant  1995      R   93 min
# 7577           The Swan Princess: A Royal Wedding  2020      G   83 min
#
#                                         Genre  \
# 0                        Action, Drama, Sport
# 1                  Action, Adventure, Fantasy
# 2                Animation, Adventure, Comedy
# 3                Animation, Adventure, Comedy
# 4                    Action, Adventure, Drama
# ...                                       ...
# 7573                   Comedy, Romance, Sport
# 7574             Animation, Action, Adventure
# 7575                            Comedy, Drama
# 7576  Action, Crime, Horror, Sci-Fi, Thriller
# 7577             Animation, Adventure, Comedy
#
#                                           Director  \
# 0                                Michael B. Jordan
# 1                                    James Cameron
# 2     Aaron Horvath, Michael Jelenic, Pierre Leduc
# 3                        Juan Jesús García Galocha
# 4                        Herbert James Winterstern
# ...                                            ...
# 7573                                Marco Schnabel
# 7574                Yasuto Nishikata, Noriyuki Abe
# 7575                                    Mike Mills
# 7576                                  Bradford May
# 7577                                  Richard Rich
#
#                                                  Actors  \
# 0     Michael B. Jordan, Tessa Thompson, Jonathan Ma...
# 1        Sam Worthington, Zoe Saldana, Sigourney Weaver
# 2             Chris Pratt, Anya Taylor-Joy, Charlie Day
# 3         Óscar Barberán, Ana Esther Alborg, Luis Reina
# 4               Skeet Ulrich, Anne Heche, Daniel Diemer
# ...                                                 ...
# 7573             Mike Myers, Jessica Alba, Romany Malco
# 7574               Yûki Kaji, Sora Amamiya, Misaki Kuno
# 7575         Annette Bening, Elle Fanning, Greta Gerwig
# 7576  Larry Drake, Arnold Vosloo, Kim Delaney, Renée...
# 7577        Nina Herzog, Yuri Lowenthal, Joseph Medrano
#
#                                                    Plot  \
# 0     Adonis has been thriving in both his career an...
# 1     Jake Sully lives with his newfound family form...
# 2     A plumber named Mario travels through an under...
# 3     It follows three mummies as they end up in pre...
# 4     A teenage boy runs away to follow in the foots...
# ...                                                 ...
# 7573  Pitka, an American raised outside of his count...
# 7574  The Seven Deadly Sins travel to the Sky Temple...
# 7575  In 1979 Santa Barbara, Dorothea is a determine...
# 7576  Darkman and Durant return and they hate each o...
# 7577  Princess Odette and Prince Derek are going to ...
#
#                                      Country  \
# 0                              United States
# 1                              United States
# 2                       United States, Japan
# 3                       Spain, United States
# 4                              United States
# ...                                      ...
# 7573  United Kingdom, Germany, United States
# 7574                                   Japan
# 7575                           United States
# 7576                             USA, Canada
# 7577                           United States
#
#                                                  Awards Metascore imdbRating  \
# 0                                        28 nominations        73        6.7
# 1          Won 1 Oscar. 75 wins & 150 nominations total        67        7.5
# 2                               2 wins & 47 nominations        46        7.0
# 3                                         3 nominations       N/A        5.9
# 4                                 3 wins & 1 nomination       N/A        4.4
# ...                                                 ...       ...        ...
# 7573                             5 wins & 8 nominations        24        3.8
# 7574                                       1 nomination       N/A        7.0
# 7575  Nominated for 1 Oscar. 15 wins & 82 nomination...        83        7.3
# 7576                                                N/A       N/A        5.1
# 7577                                                N/A       N/A        5.6
#
#      imdbVotes      imdbID
# 0       95,684  tt11145118
# 1      509,749   tt1630029
# 2      246,752   tt6718170
# 3        9,366  tt23177868
# 4        3,251  tt10559102
# ...        ...         ...
# 7573    55,340   tt0811138
# 7574     5,632   tt9089294
# 7575    50,036   tt4385888
# 7576     5,007   tt0109552
# 7577       115  tt12398350
#
# [7578 rows x 14 columns]

# %%
# Merge the dataframes on the 'Title' column
df_merged = pd.merge(df_api, df_copy, on='Title', how='inner')

# Display the merged dataframe
print(df_merged.head())
# Out:
#                          Title  Year  Rated  Runtime  \
# 0                    Creed III  2023  PG-13  116 min
# 1     Avatar: The Way of Water  2022  PG-13  192 min
# 2  The Super Mario Bros. Movie  2023     PG   92 min
# 3                      Mummies  2023     PG   88 min
# 4                    Supercell  2023  PG-13  100 min
#
#                           Genre                                      Director  \
# 0          Action, Drama, Sport                             Michael B. Jordan
# 1    Action, Adventure, Fantasy                                 James Cameron
# 2  Animation, Adventure, Comedy  Aaron Horvath, Michael Jelenic, Pierre Leduc
# 3  Animation, Adventure, Comedy                     Juan Jesús García Galocha
# 4      Action, Adventure, Drama                     Herbert James Winterstern
#
#                                               Actors  \
# 0  Michael B. Jordan, Tessa Thompson, Jonathan Ma...
# 1     Sam Worthington, Zoe Saldana, Sigourney Weaver
# 2          Chris Pratt, Anya Taylor-Joy, Charlie Day
# 3      Óscar Barberán, Ana Esther Alborg, Luis Reina
# 4            Skeet Ulrich, Anne Heche, Daniel Diemer
#
#                                                 Plot               Country  \
# 0  Adonis has been thriving in both his career an...         United States
# 1  Jake Sully lives with his newfound family form...         United States
# 2  A plumber named Mario travels through an under...  United States, Japan
# 3  It follows three mummies as they end up in pre...  Spain, United States
# 4  A teenage boy runs away to follow in the foots...         United States
#
#                                          Awards Metascore imdbRating  \
# 0                                28 nominations        73        6.7
# 1  Won 1 Oscar. 75 wins & 150 nominations total        67        7.5
# 2                       2 wins & 47 nominations        46        7.0
# 3                                 3 nominations       N/A        5.9
# 4                         3 wins & 1 nomination       N/A        4.4
#
#   imdbVotes      imdbID            orig_lang     budget_x       revenue  \
# 0    95,684  tt11145118              English   75000000.0  2.716167e+08
# 1   509,749   tt1630029              English  460000000.0  2.316795e+09
# 2   246,752   tt6718170              English  100000000.0  7.244590e+08
# 3     9,366  tt23177868   Spanish, Castilian   12300000.0  3.420000e+07
# 4     3,251  tt10559102              English   77000000.0  3.409420e+08
#
#       date_x
# 0 2023-03-02
# 1 2022-12-15
# 2 2023-04-05
# 3 2023-01-05
# 4 2023-03-17

# %%
# Drop duplicates based on the 'Title' and 'imdbID' columns
df_merged.drop_duplicates(subset=['Title', 'imdbID'], inplace=True)

# %%
# Reset the index of the merged dataframe
df_merged.reset_index(drop=True, inplace=True)

# %%
# Create a copy of the merged dataframe
df_clean = df_merged.copy()
df_clean
# Out:
#                                             Title  Year  Rated  Runtime  \
# 0                                       Creed III  2023  PG-13  116 min
# 1                        Avatar: The Way of Water  2022  PG-13  192 min
# 2                     The Super Mario Bros. Movie  2023     PG   92 min
# 3                                         Mummies  2023     PG   88 min
# 4                                       Supercell  2023  PG-13  100 min
# ...                                           ...   ...    ...      ...
# 7095                                The Love Guru  2008  PG-13   87 min
# 7096  The Seven Deadly Sins: Prisoners of the Sky  2018  TV-14   99 min
# 7097                           20th Century Women  2016      R  119 min
# 7098             Darkman II: The Return of Durant  1995      R   93 min
# 7099           The Swan Princess: A Royal Wedding  2020      G   83 min
#
#                                         Genre  \
# 0                        Action, Drama, Sport
# 1                  Action, Adventure, Fantasy
# 2                Animation, Adventure, Comedy
# 3                Animation, Adventure, Comedy
# 4                    Action, Adventure, Drama
# ...                                       ...
# 7095                   Comedy, Romance, Sport
# 7096             Animation, Action, Adventure
# 7097                            Comedy, Drama
# 7098  Action, Crime, Horror, Sci-Fi, Thriller
# 7099             Animation, Adventure, Comedy
#
#                                           Director  \
# 0                                Michael B. Jordan
# 1                                    James Cameron
# 2     Aaron Horvath, Michael Jelenic, Pierre Leduc
# 3                        Juan Jesús García Galocha
# 4                        Herbert James Winterstern
# ...                                            ...
# 7095                                Marco Schnabel
# 7096                Yasuto Nishikata, Noriyuki Abe
# 7097                                    Mike Mills
# 7098                                  Bradford May
# 7099                                  Richard Rich
#
#                                                  Actors  \
# 0     Michael B. Jordan, Tessa Thompson, Jonathan Ma...
# 1        Sam Worthington, Zoe Saldana, Sigourney Weaver
# 2             Chris Pratt, Anya Taylor-Joy, Charlie Day
# 3         Óscar Barberán, Ana Esther Alborg, Luis Reina
# 4               Skeet Ulrich, Anne Heche, Daniel Diemer
# ...                                                 ...
# 7095             Mike Myers, Jessica Alba, Romany Malco
# 7096               Yûki Kaji, Sora Amamiya, Misaki Kuno
# 7097         Annette Bening, Elle Fanning, Greta Gerwig
# 7098  Larry Drake, Arnold Vosloo, Kim Delaney, Renée...
# 7099        Nina Herzog, Yuri Lowenthal, Joseph Medrano
#
#                                                    Plot  \
# 0     Adonis has been thriving in both his career an...
# 1     Jake Sully lives with his newfound family form...
# 2     A plumber named Mario travels through an under...
# 3     It follows three mummies as they end up in pre...
# 4     A teenage boy runs away to follow in the foots...
# ...                                                 ...
# 7095  Pitka, an American raised outside of his count...
# 7096  The Seven Deadly Sins travel to the Sky Temple...
# 7097  In 1979 Santa Barbara, Dorothea is a determine...
# 7098  Darkman and Durant return and they hate each o...
# 7099  Princess Odette and Prince Derek are going to ...
#
#                                      Country  \
# 0                              United States
# 1                              United States
# 2                       United States, Japan
# 3                       Spain, United States
# 4                              United States
# ...                                      ...
# 7095  United Kingdom, Germany, United States
# 7096                                   Japan
# 7097                           United States
# 7098                             USA, Canada
# 7099                           United States
#
#                                                  Awards Metascore imdbRating  \
# 0                                        28 nominations        73        6.7
# 1          Won 1 Oscar. 75 wins & 150 nominations total        67        7.5
# 2                               2 wins & 47 nominations        46        7.0
# 3                                         3 nominations       N/A        5.9
# 4                                 3 wins & 1 nomination       N/A        4.4
# ...                                                 ...       ...        ...
# 7095                             5 wins & 8 nominations        24        3.8
# 7096                                       1 nomination       N/A        7.0
# 7097  Nominated for 1 Oscar. 15 wins & 82 nomination...        83        7.3
# 7098                                                N/A       N/A        5.1
# 7099                                                N/A       N/A        5.6
#
#      imdbVotes      imdbID            orig_lang     budget_x       revenue  \
# 0       95,684  tt11145118              English   75000000.0  2.716167e+08
# 1      509,749   tt1630029              English  460000000.0  2.316795e+09
# 2      246,752   tt6718170              English  100000000.0  7.244590e+08
# 3        9,366  tt23177868   Spanish, Castilian   12300000.0  3.420000e+07
# 4        3,251  tt10559102              English   77000000.0  3.409420e+08
# ...        ...         ...                  ...          ...           ...
# 7095    55,340   tt0811138              English   62000000.0  4.015902e+07
# 7096     5,632   tt9089294             Japanese   62600000.0  7.060021e+08
# 7097    50,036   tt4385888              English    7000000.0  9.353729e+06
# 7098     5,007   tt0109552              English  116000000.0  4.756613e+08
# 7099       115  tt12398350              English   92400000.0  5.394018e+08
#
#          date_x
# 0    2023-03-02
# 1    2022-12-15
# 2    2023-04-05
# 3    2023-01-05
# 4    2023-03-17
# ...         ...
# 7095 2008-07-10
# 7096 2018-08-18
# 7097 2016-12-28
# 7098 1995-07-11
# 7099 2020-07-20
#
# [7100 rows x 18 columns]

# %%
# DATA CLEANING : Column names
df_clean.columns = [col.lower() for col in df_clean.columns]
df_clean.rename(columns={'imdbrating': 'imdb_rating', 'imdbvotes': 'imdb_votes', 'imdbid':'imdb_id', 'orig_lang': 'languages', 'budget_x': 'budget_M', 'revenue': 'US_CA_revenue_M', 'date_x': 'release_date'}, inplace=True)

# %%
# Revenue in $M
df_clean["US_CA_revenue_M"] = (df_clean["US_CA_revenue_M"]/1000000).round(2)
df_clean["budget_M"] = (df_clean["budget_M"]/1000000).round(2)

# %%
# Remove the 'min' suffix and extra whitespace from the 'runtime' column
df_clean["runtime"] = df_clean["runtime"].apply(lambda x: x.strip().split(" min")[0] if "min" in x else x.strip())

# Check the unique values to ensure whitespaces are removed
print(df_clean["runtime"].unique())
# Out:
# ['116' '192' '92' '88' '100' '95' '169' '102' '24' '76' '122' '90' '161'
#  '103' '107' '111' '14' '117' '99' '127' '130' '91' '125' '94' '124' '2'
#  '82' '83' '101' '84' '105' '93' '126' '3' '97' '134' '45' '96' '162'
#  '118' '85' '138' '148' '60' '106' '147' '132' 'N/A' '112' '139' '135'
#  '149' '115' '87' '133' '141' '119' '176' '143' '98' '77' '110' '89' '114'
#  '75' '30' '86' '189' '136' '137' '142' '73' '104' '129' '157' '153' '109'
#  '150' '180' '187' '181' '140' '146' '113' '242' '158' '156' '81' '108'
#  '194' '123' '80' '40' '128' '151' '42' '79' '131' '144' '120' '46' '70'
#  '20' '121' '72' '78' '178' '44' '212' '165' '65' '55' '52' '23' '201'
#  '152' '179' '163' '363' '5' '51' '57' '154' '29' '159' '34' '43' '10'
#  '25' '9' '155' '164' '6' '240' '262' '13' '36' '26' '22' '71' '8' '33'
#  '27' '1' '56' '54' '59' '170' '69' '31S' '7' '173' '145' '183' '74' '35'
#  '166' '53' '61' '167' '38' '21' '67' '68' '19' '64' '63' '209' '48' '168'
#  '50' '175' '15' '32' '41' '247' '28' '4' '172' '498' '171' '31' '47' '12'
#  '18' '220' '16' '17' '160' '32S' '37' '27S' '11' '182' '66' '206' '188'
#  '184' '264' '29S' '239' '58' '21S' '185' '62' '186' '400' '386']

# %%
# Remove rows where the 'runtime' column ends with 'S'
df_clean = df_clean[~df_clean['runtime'].str.endswith('S')]

# Display the DataFrame after filtering
print(df_clean["runtime"].unique())
# Out:
# ['116' '192' '92' '88' '100' '95' '169' '102' '24' '76' '122' '90' '161'
#  '103' '107' '111' '14' '117' '99' '127' '130' '91' '125' '94' '124' '2'
#  '82' '83' '101' '84' '105' '93' '126' '3' '97' '134' '45' '96' '162'
#  '118' '85' '138' '148' '60' '106' '147' '132' 'N/A' '112' '139' '135'
#  '149' '115' '87' '133' '141' '119' '176' '143' '98' '77' '110' '89' '114'
#  '75' '30' '86' '189' '136' '137' '142' '73' '104' '129' '157' '153' '109'
#  '150' '180' '187' '181' '140' '146' '113' '242' '158' '156' '81' '108'
#  '194' '123' '80' '40' '128' '151' '42' '79' '131' '144' '120' '46' '70'
#  '20' '121' '72' '78' '178' '44' '212' '165' '65' '55' '52' '23' '201'
#  '152' '179' '163' '363' '5' '51' '57' '154' '29' '159' '34' '43' '10'
#  '25' '9' '155' '164' '6' '240' '262' '13' '36' '26' '22' '71' '8' '33'
#  '27' '1' '56' '54' '59' '170' '69' '7' '173' '145' '183' '74' '35' '166'
#  '53' '61' '167' '38' '21' '67' '68' '19' '64' '63' '209' '48' '168' '50'
#  '175' '15' '32' '41' '247' '28' '4' '172' '498' '171' '31' '47' '12' '18'
#  '220' '16' '17' '160' '37' '11' '182' '66' '206' '188' '184' '264' '239'
#  '58' '185' '62' '186' '400' '386']

# %%
# Apply the extraction function to the 'awards' column and create two new columns: 'wins' and 'nominations'
df_clean[['wins', 'nominations']] = df_clean['awards'].apply(lambda x: pd.Series(extract_awards_info(x)))

# Display the updated DataFrame with the extracted 'wins' and 'nominations' columns
print(df_clean[['awards', 'wins', 'nominations']])
# Out:
#                                                  awards  wins  nominations
# 0                                        28 nominations     0           28
# 1          Won 1 Oscar. 75 wins & 150 nominations total    76          150
# 2                               2 wins & 47 nominations     2           47
# 3                                         3 nominations     0            3
# 4                                 3 wins & 1 nomination     3            1
# ...                                                 ...   ...          ...
# 7095                             5 wins & 8 nominations     5            8
# 7096                                       1 nomination     0            1
# 7097  Nominated for 1 Oscar. 15 wins & 82 nomination...    15           82
# 7098                                                N/A     0            0
# 7099                                                N/A     0            0
#
# [7095 rows x 3 columns]
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\2350869491.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[['wins', 'nominations']] = df_clean['awards'].apply(lambda x: pd.Series(extract_awards_info(x)))
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\2350869491.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[['wins', 'nominations']] = df_clean['awards'].apply(lambda x: pd.Series(extract_awards_info(x)))

# %%
# Define a dictionary to map specific ratings to broader categories
rating_mapping = {
    'G': 'G', 'TV-G': 'G', 'TV-Y': 'G', 'TV-Y7': 'G',
    'PG': 'PG', 'PG-13': 'PG', 'TV-PG': 'PG', 'TV-Y7-FV': 'G',
    'R': 'R', 'TV-MA': 'R', 'NC-17': 'R', 'MA-17': 'R', '18+': 'R', 'X': 'R',
    'Not Rated': 'Unrated', 'Unrated': 'Unrated', 'N/A': 'Unrated',
    'Approved': 'Unrated', 'Passed': 'Unrated', 'E': 'Unrated',
    '13+': 'PG', '16+': 'R', '12': 'PG', 'TV-14': 'PG', 'TV-Y7-FV': 'G'
}

# Apply the mapping to the 'rated' column
df_clean['rated'] = df_clean['rated'].map(rating_mapping)

# Check the unique values after mapping to ensure they are clean
print(df_clean['rated'].unique())
# Out:
# ['PG' 'R' 'Unrated' 'G']
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\1524140635.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['rated'] = df_clean['rated'].map(rating_mapping)

# %%
# Changing the type of metascore to integer
df_clean.metascore = df_clean.metascore.apply(lambda x: int(x)/10 if x.isdigit() else None)
df_clean.metascore.unique()
# Out:
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\1507799421.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.metascore = df_clean.metascore.apply(lambda x: int(x)/10 if x.isdigit() else None)
# array([ 7.3,  6.7,  4.6,  nan,  5.4,  7.8,  8.1,  4.4,  4.5,  6.3,  3.7,
#         5.3,  6.2,  4.7,  4. ,  4.1,  7.2,  4.8,  7.5,  6. ,  3.8,  5.1,
#         5. ,  1.9,  5.8,  6.1,  8.3,  6.6,  5.7,  5.9,  6.8,  7.1,  7.9,
#         6.5,  7.6,  5.5,  7.7,  6.9,  3. ,  5.6,  8.2,  5.2,  4.9,  8.4,
#         7. ,  7.4,  3.4,  8. ,  8.8,  6.4,  4.2,  8.6,  3.5,  8.5,  2.9,
#         3.1,  8.7,  9.3,  3.2,  3.6,  9.6,  4.3,  9.9,  9.4,  1.4,  3.3,
#         9.2,  9. ,  3.9,  1.7,  2.8,  2.7,  2.6,  9.5,  9.1,  2.5,  2. ,
#         8.9,  2.2,  1.6,  2.3,  2.4,  2.1,  9.8,  1.2,  0.9,  1.8,  1.3,
#         1.1,  1. , 10. ,  1.5,  9.7,  0.7,  0.6])

# %%
# Changing the type of imdb_rating to integer
df_clean.imdb_rating = df_clean.imdb_rating.apply(lambda x: float(x) if x != "N/A" else None)
# Out:
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\485114113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.imdb_rating = df_clean.imdb_rating.apply(lambda x: float(x) if x != "N/A" else None)

# %%
# Apply the function to each row to create the 'aggregated_score' column
df_clean['aggregated_score'] = df_clean.apply(compute_aggregated_score, axis=1)

# Display the updated DataFrame with the new column
print(df_clean[['imdb_rating', 'metascore', 'aggregated_score']])
# Out:
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\2368024622.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['aggregated_score'] = df_clean.apply(compute_aggregated_score, axis=1)
#       imdb_rating  metascore  aggregated_score
# 0             6.7        7.3               7.0
# 1             7.5        6.7               7.1
# 2             7.0        4.6               5.8
# 3             5.9        NaN               5.9
# 4             4.4        NaN               4.4
# ...           ...        ...               ...
# 7095          3.8        2.4               3.1
# 7096          7.0        NaN               7.0
# 7097          7.3        8.3               7.8
# 7098          5.1        NaN               5.1
# 7099          5.6        NaN               5.6
#
# [7095 rows x 3 columns]

# %%
# Set the 'imdb_votes' column to a $M numeric base
df_clean.imdb_votes_thousands = df_clean.imdb_votes.apply(lambda x: int(x.replace(',', ''))/1000 if x != "N/A" else None)
print(df_clean.imdb_votes.unique())
# Out:
# ['95,684' '509,749' '246,752' ... '5,632' '50,036' '115']
# C:\Users\olivi\AppData\Local\Temp\ipykernel_5072\2569922504.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_clean.imdb_votes_thousands = df_clean.imdb_votes.apply(lambda x: int(x.replace(',', ''))/1000 if x != "N/A" else None)

# %%
#Another copy of df_clean2
df_clean2 = df_clean.copy()

# %%
gross_values = []

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}



for imdb_id in df_clean['imdb_id']:

    gross_value = scrape_gross(imdb_id)
    gross_values.append(gross_value)


df_clean2['cumulative_worldwide_gross'] = gross_values
# Out:
# Success: tt11145118 returned status 200
# Success: tt1630029 returned status 200
# Success: tt6718170 returned status 200
# Success: tt23177868 returned status 200
# Success: tt10559102 returned status 200
# Success: tt14209916 returned status 200
# Success: tt10366206 returned status 200
# Success: tt3915174 returned status 200
# Success: tt2560140 returned status 200
# Success: tt21281688 returned status 200
# Success: tt0070047 returned status 200
# Success: tt15255288 returned status 200
# Success: tt9114286 returned status 200
# Success: tt13375076 returned status 200
# Success: tt4471908 returned status 200
# Success: tt15679400 returned status 200
# Success: tt9663168 returned status 200
# Success: tt7584264 returned status 200
# Success: tt18092672 returned status 200
# Success: tt2560092 returned status 200
# Success: tt5884796 returned status 200
# Success: tt0335345 returned status 200
# Success: tt10151854 returned status 200
# Success: tt14993352 returned status 200
# Success: tt21426434 returned status 200
# Success: tt6443346 returned status 200
# Success: tt26739529 returned status 200
# Success: tt8760708 returned status 200
# Success: tt10954600 returned status 200
# Success: tt19869024 returned status 200
# Success: tt10726424 returned status 200
# Success: tt21199996 returned status 200
# Success: tt15427420 returned status 200
# Success: tt4425200 returned status 200
# Success: tt14642626 returned status 200
# Success: tt11696342 returned status 200
# Success: tt9686790 returned status 200
# Success: tt6146586 returned status 200
# Success: tt22769820 returned status 200
# Success: tt15325794 returned status 200
# Success: tt17219636 returned status 200
# Success: tt13614388 returned status 200
# Success: tt13833688 returned status 200
# Success: tt9271672 returned status 200
# Success: tt9853500 returned status 200
# Success: tt24082346 returned status 200
# Success: tt11718516 returned status 200
# Success: tt7405458 returned status 200
# Success: tt15339570 returned status 200
# Success: tt2906216 returned status 200
# Success: tt11116912 returned status 200
# Success: tt12412888 returned status 200
# Success: tt9719256 returned status 200
# Success: tt22695080 returned status 200
# Success: tt1465840 returned status 200
# Success: tt1745960 returned status 200
# Success: tt13929998 returned status 200
# Success: tt0074483 returned status 200
# Success: tt17663992 returned status 200
# Success: tt0499549 returned status 200
# Success: tt12311620 returned status 200
# Success: tt12758060 returned status 200
# Success: tt12261776 returned status 200
# Success: tt10648342 returned status 200
# Success: tt9183978 returned status 200
# Success: tt10403420 returned status 200
# Success: tt2911666 returned status 200
# Success: tt10872600 returned status 200
# Success: tt21094994 returned status 200
# Success: tt18526902 returned status 200
# Success: tt1488589 returned status 200
# Success: tt8101238 returned status 200
# Success: tt14614892 returned status 200
# Success: tt11212572 returned status 200
# Success: tt11866324 returned status 200
# Success: tt0423668 returned status 200
# Success: tt8883486 returned status 200
# Success: tt26931203 returned status 200
# Success: tt14873054 returned status 200
# Success: tt8041270 returned status 200
# Success: tt23546646 returned status 200
# Success: tt0448115 returned status 200
# Success: tt4722678 returned status 200
# Success: tt1016150 returned status 200
# Success: tt12003946 returned status 200
# Success: tt0117571 returned status 200
# Success: tt7693316 returned status 200
# Success: tt8093700 returned status 200
# Success: tt13345606 returned status 200
# Success: tt12965390 returned status 200
# Success: tt9419884 returned status 200
# Success: tt1655444 returned status 200
# Success: tt4154756 returned status 200
# Success: tt15474916 returned status 200
# Success: tt22394702 returned status 200
# Success: tt10298840 returned status 200
# Success: tt13932410 returned status 200
# Success: tt5113044 returned status 200
# Success: tt6343314 returned status 200
# Success: tt3076658 returned status 200
# Success: tt13223398 returned status 200
# Success: tt5433140 returned status 200
# Success: tt15229674 returned status 200
# Success: tt11083552 returned status 200
# Success: tt14121726 returned status 200
# Success: tt8097030 returned status 200
# Success: tt2953050 returned status 200
# Success: tt14668196 returned status 200
# Success: tt16280138 returned status 200
# Success: tt14668630 returned status 200
# Success: tt5122626 returned status 200
# Success: tt2119532 returned status 200
# Success: tt0489327 returned status 200
# Success: tt13103732 returned status 200
# Success: tt14331144 returned status 200
# Success: tt1877830 returned status 200
# Success: tt6598238 returned status 200
# Success: tt0363771 returned status 200
# Success: tt10362566 returned status 200
# Success: tt11186952 returned status 200
# Success: tt13349892 returned status 200
# Success: tt7286156 returned status 200
# Success: tt16419074 returned status 200
# Success: tt1596342 returned status 200
# Success: tt7214954 returned status 200
# Success: tt12593682 returned status 200
# Success: tt13623880 returned status 200
# Success: tt12610794 returned status 200
# Success: tt6467266 returned status 200
# Success: tt12550376 returned status 200
# Success: tt0126029 returned status 200
# Success: tt22900124 returned status 200
# Success: tt26763229 returned status 200
# Success: tt13055982 returned status 200
# Success: tt14846026 returned status 200
# Success: tt7985704 returned status 200
# Success: tt21862626 returned status 200
# Success: tt6710474 returned status 200
# Success: tt11069038 returned status 200
# Success: tt13468602 returned status 200
# Success: tt13544716 returned status 200
# Success: tt0112206 returned status 200
# Success: tt12882620 returned status 200
# Success: tt15441472 returned status 200
# Success: tt1618434 returned status 200
# Success: tt10640346 returned status 200
# Success: tt13320622 returned status 200
# Success: tt21435436 returned status 200
# Success: tt13882736 returned status 200
# Success: tt15721650 returned status 200
# Success: tt0295297 returned status 200
# Success: tt16900880 returned status 200
# Success: tt13857556 returned status 200
# Success: tt7097896 returned status 200
# Success: tt11160650 returned status 200
# Success: tt1464335 returned status 200
# Success: tt8912936 returned status 200
# Success: tt5834426 returned status 200
# Success: tt15445056 returned status 200
# Success: tt10483152 returned status 200
# Success: tt15486810 returned status 200
# Success: tt4123432 returned status 200
# Success: tt3606752 returned status 200
# Success: tt1535970 returned status 200
# Success: tt15528292 returned status 200
# Success: tt0816692 returned status 200
# Success: tt13051810 returned status 200
# Success: tt15340724 returned status 200
# Success: tt22774688 returned status 200
# Success: tt2560078 returned status 200
# Success: tt9660502 returned status 200
# Success: tt0327597 returned status 200
# Success: tt3155298 returned status 200
# Success: tt0330373 returned status 200
# Success: tt10399608 returned status 200
# Success: tt11851548 returned status 200
# Success: tt5058148 returned status 200
# Success: tt4139588 returned status 200
# Success: tt0417741 returned status 200
# Success: tt32909363 returned status 200
# Success: tt0425308 returned status 200
# Success: tt15275256 returned status 200
# Success: tt1470171 returned status 200
# Success: tt0848228 returned status 200
# Success: tt15654800 returned status 200
# Success: tt1528100 returned status 200
# Success: tt7319486 returned status 200
# Success: tt0097757 returned status 200
# Success: tt0993846 returned status 200
# Success: tt13365876 returned status 200
# Success: tt0765010 returned status 200
# Success: tt0304141 returned status 200
# Success: tt0081291 returned status 200
# Success: tt8178634 returned status 200
# Success: tt13056052 returned status 200
# Success: tt7144666 returned status 200
# Success: tt5090568 returned status 200
# Success: tt4154796 returned status 200
# Success: tt9362722 returned status 200
# Success: tt10171796 returned status 200
# Success: tt0373889 returned status 200
# Success: tt11138512 returned status 200
# Success: tt4294970 returned status 200
# Success: tt15038118 returned status 200
# Success: tt13070038 returned status 200
# Success: tt14824590 returned status 200
# Success: tt21106646 returned status 200
# Success: tt11909878 returned status 200
# Success: tt5108870 returned status 200
# Success: tt1216475 returned status 200
# Success: tt0398286 returned status 200
# Success: tt2322441 returned status 200
# Success: tt1201607 returned status 200
# Success: tt1454029 returned status 200
# Success: tt0198781 returned status 200
# Success: tt13634480 returned status 200
# Success: tt5500218 returned status 200
# Success: tt5034838 returned status 200
# Success: tt14656632 returned status 200
# Success: tt9376612 returned status 200
# Success: tt12361974 returned status 200
# Success: tt10298810 returned status 200
# Success: tt2182019 returned status 200
# Success: tt6018030 returned status 200
# Success: tt17595262 returned status 200
# Success: tt16428256 returned status 200
# Success: tt0449088 returned status 200
# Success: tt2935622 returned status 200
# Success: tt4624366 returned status 200
# Success: tt0298148 returned status 200
# Success: tt11291274 returned status 200
# Success: tt4477536 returned status 200
# Success: tt4633694 returned status 200
# Success: tt0926084 returned status 200
# Success: tt15255876 returned status 200
# Success: tt11535228 returned status 200
# Success: tt0469494 returned status 200
# Success: tt11827628 returned status 200
# Success: tt0435528 returned status 200
# Success: tt2872518 returned status 200
# Success: tt9032400 returned status 200
# Success: tt11252248 returned status 200
# Success: tt2400463 returned status 200
# Success: tt7069210 returned status 200
# Success: tt1365048 returned status 200
# Success: tt0421082 returned status 200
# Success: tt0293429 returned status 200
# Success: tt0325980 returned status 200
# Success: tt2397461 returned status 200
# Success: tt13117446 returned status 200
# Success: tt3228774 returned status 200
# Success: tt6334354 returned status 200
# Success: tt15494038 returned status 200
# Success: tt8115900 returned status 200
# Success: tt2714380 returned status 200
# Success: tt3717532 returned status 200
# Success: tt1298650 returned status 200
# Success: tt16127696 returned status 200
# Success: tt17321230 returned status 200
# Success: tt2380307 returned status 200
# Success: tt9288046 returned status 200
# Success: tt0114709 returned status 200
# Success: tt3416670 returned status 200
# Success: tt8561086 returned status 200
# Success: tt18671386 returned status 200
# Success: tt0120338 returned status 200
# Success: tt1951265 returned status 200
# Success: tt3289956 returned status 200
# Success: tt15391770 returned status 200
# Success: tt12764628 returned status 200
# Success: tt11514780 returned status 200
# Success: tt15575470 returned status 200
# Success: tt0090881 returned status 200
# Success: tt2262315 returned status 200
# Success: tt3210686 returned status 200
# Success: tt15052770 returned status 200
# Success: tt6920084 returned status 200
# Success: tt14138650 returned status 200
# Success: tt2395427 returned status 200
# Success: tt2674426 returned status 200
# Success: tt12801262 returned status 200
# Success: tt0383574 returned status 200
# Success: tt9764362 returned status 200
# Success: tt0268380 returned status 200
# Success: tt11951334 returned status 200
# Success: tt0892791 returned status 200
# Success: tt4513678 returned status 200
# Success: tt3794354 returned status 200
# Success: tt3819668 returned status 200
# Success: tt13623136 returned status 200
# Success: tt14001894 returned status 200
# Success: tt0780521 returned status 200
# Success: tt12996154 returned status 200
# Success: tt18747542 returned status 200
# Success: tt19724142 returned status 200
# Success: tt14042038 returned status 200
# Success: tt2948356 returned status 200
# Success: tt3120944 returned status 200
# Success: tt23343786 returned status 200
# Success: tt6264654 returned status 200
# Success: tt21817022 returned status 200
# Success: tt1650043 returned status 200
# Success: tt1228705 returned status 200
# Success: tt1457767 returned status 200
# Success: tt8811670 returned status 200
# Success: tt1790864 returned status 200
# Success: tt14201576 returned status 200
# Success: tt6856242 returned status 200
# Success: tt2310332 returned status 200
# Success: tt5360996 returned status 200
# Success: tt7765232 returned status 200
# Success: tt7991608 returned status 200
# Success: tt22526694 returned status 200
# Success: tt13560574 returned status 200
# Success: tt2850386 returned status 200
# Success: tt4618398 returned status 200
# Success: tt3501632 returned status 200
# Success: tt1517268 returned status 200
# Success: tt1959490 returned status 200
# Success: tt13884144 returned status 200
# Success: tt14228078 returned status 200
# Success: tt14641788 returned status 200
# Success: tt0478970 returned status 200
# Success: tt4520988 returned status 200
# Success: tt0413267 returned status 200
# Success: tt0382932 returned status 200
# Success: tt15262370 returned status 200
# Success: tt5109280 returned status 200
# Success: tt13320662 returned status 200
# Success: tt11832046 returned status 200
# Success: tt1431045 returned status 200
# Success: tt1979388 returned status 200
# Success: tt10242388 returned status 200
# Success: tt7798604 returned status 200
# Success: tt7388562 returned status 200
# Success: tt0433035 returned status 200
# Success: tt10838180 returned status 200
# Success: tt5315210 returned status 200
# Success: tt0032910 returned status 200
# Success: tt9777666 returned status 200
# Success: tt0317219 returned status 200
# Success: tt17196124 returned status 200
# Success: tt20917338 returned status 200
# Success: tt12823454 returned status 200
# Success: tt5311514 returned status 200
# Success: tt0448694 returned status 200
# Success: tt4630562 returned status 200
# Success: tt16437278 returned status 200
# Success: tt12004038 returned status 200
# Success: tt1649418 returned status 200
# Success: tt11847410 returned status 200
# Success: tt0120762 returned status 200
# Success: tt17042714 returned status 200
# Success: tt2245084 returned status 200
# Success: tt7322224 returned status 200
# Success: tt16527290 returned status 200
# Success: tt3609402 returned status 200
# Success: tt2096673 returned status 200
# Success: tt2713180 returned status 200
# Success: tt21301662 returned status 200
# Success: tt12530246 returned status 200
# Success: tt13606158 returned status 200
# Success: tt13069986 returned status 200
# Success: tt13611770 returned status 200
# Success: tt5167966 returned status 200
# Success: tt3554046 returned status 200
# Success: tt7888964 returned status 200
# Success: tt7527028 returned status 200
# Success: tt1999167 returned status 200
# Success: tt4281724 returned status 200
# Success: tt13924926 returned status 200
# Success: tt0948470 returned status 200
# Success: tt1288558 returned status 200
# Success: tt13483866 returned status 200
# Success: tt10362466 returned status 200
# Success: tt8332922 returned status 200
# Success: tt1099212 returned status 200
# Success: tt7375466 returned status 200
# Success: tt2250912 returned status 200
# Success: tt0347149 returned status 200
# Success: tt0816711 returned status 200
# Success: tt0367594 returned status 200
# Success: tt15721088 returned status 200
# Success: tt2386490 returned status 200
# Success: tt15360384 returned status 200
# Success: tt0093177 returned status 200
# Success: tt1663662 returned status 200
# Success: tt11107074 returned status 200
# Success: tt4126476 returned status 200
# Success: tt1119646 returned status 200
# Success: tt2463208 returned status 200
# Success: tt21919270 returned status 200
# Success: tt23036332 returned status 200
# Success: tt12335692 returned status 200
# Success: tt0120917 returned status 200
# Success: tt13406136 returned status 200
# Success: tt0110357 returned status 200
# Success: tt0870154 returned status 200
# Success: tt5814060 returned status 200
# Success: tt2933474 returned status 200
# Success: tt15438542 returned status 200
# Success: tt0120783 returned status 200
# Success: tt0484382 returned status 200
# Success: tt1447981 returned status 200
# Success: tt2820852 returned status 200
# Success: tt3065204 returned status 200
# Success: tt15713012 returned status 200
# Success: tt1375666 returned status 200
# Success: tt2294629 returned status 200
# Success: tt15474126 returned status 200
# Success: tt6652708 returned status 200
# Success: tt0120794 returned status 200
# Success: tt11348232 returned status 200
# Success: tt7349950 returned status 200
# Success: tt9419056 returned status 200
# Success: tt0120737 returned status 200
# Success: tt22028912 returned status 200
# Success: tt14967618 returned status 200
# Success: tt13717538 returned status 200
# Success: tt3480822 returned status 200
# Success: tt0201484 returned status 200
# Success: tt10949028 returned status 200
# Success: tt4459134 returned status 200
# Success: tt0266543 returned status 200
# Success: tt0052618 returned status 200
# Success: tt31434046 returned status 200
# Success: tt2191701 returned status 200
# Success: tt0800369 returned status 200
# Success: tt3498820 returned status 200
# Success: tt1211837 returned status 200
# Success: tt2109248 returned status 200
# Success: tt21237030 returned status 200
# Success: tt0264734 returned status 200
# Success: tt7504726 returned status 200
# Success: tt7550014 returned status 200
# Success: tt11125620 returned status 200
# Success: tt5779372 returned status 200
# Success: tt0087182 returned status 200
# Success: tt23623604 returned status 200
# Success: tt1049413 returned status 200
# Success: tt1790809 returned status 200
# Success: tt1872181 returned status 200
# Success: tt1080016 returned status 200
# Success: tt14668358 returned status 200
# Success: tt0120363 returned status 200
# Success: tt20418306 returned status 200
# Success: tt11358390 returned status 200
# Success: tt21933210 returned status 200
# Success: tt1375670 returned status 200
# Success: tt4846340 returned status 200
# Success: tt1325004 returned status 200
# Success: tt10665342 returned status 200
# Success: tt8649186 returned status 200
# Success: tt14967958 returned status 200
# Success: tt10323676 returned status 200
# Success: tt6951892 returned status 200
# Success: tt5463162 returned status 200
# Success: tt2126355 returned status 200
# Success: tt6654210 returned status 200
# Success: tt7838654 returned status 200
# Success: tt3231054 returned status 200
# Success: tt14033502 returned status 200
# Success: tt21477618 returned status 200
# Success: tt21293272 returned status 200
# Success: tt9685342 returned status 200
# Success: tt0245429 returned status 200
# Success: tt18070050 returned status 200
# Success: tt4325142 returned status 200
# Success: tt6475714 returned status 200
# Success: tt2637276 returned status 200
# Success: tt21440188 returned status 200
# Success: tt5116302 returned status 200
# Success: tt0142243 returned status 200
# Success: tt13314558 returned status 200
# Success: tt1648216 returned status 200
# Success: tt1951264 returned status 200
# Success: tt10954984 returned status 200
# Success: tt0480249 returned status 200
# Success: tt1599280 returned status 200
# Success: tt4428398 returned status 200
# Success: tt2802144 returned status 200
# Success: tt14060094 returned status 200
# Success: tt0167260 returned status 200
# Success: tt1981115 returned status 200
# Success: tt10648714 returned status 200
# Success: tt7745068 returned status 200
# Success: tt8186318 returned status 200
# Success: tt2948372 returned status 200
# Success: tt1397514 returned status 200
# Success: tt14935038 returned status 200
# Success: tt1673434 returned status 200
# Success: tt27161958 returned status 200
# Success: tt1524575 returned status 200
# Success: tt1951266 returned status 200
# Success: tt0175142 returned status 200
# Success: tt0468569 returned status 200
# Success: tt4257926 returned status 200
# Success: tt1979376 returned status 200
# Success: tt4823776 returned status 200
# Success: tt6587640 returned status 200
# Success: tt1300854 returned status 200
# Success: tt1446714 returned status 200
# Success: tt0435761 returned status 200
# Success: tt0120689 returned status 200
# Success: tt12876132 returned status 200
# Success: tt22437050 returned status 200
# Success: tt4465564 returned status 200
# Success: tt3896198 returned status 200
# Success: tt5095030 returned status 200
# Success: tt7286456 returned status 200
# Success: tt20168564 returned status 200
# Success: tt0360486 returned status 200
# Success: tt15790974 returned status 200
# Success: tt13133936 returned status 200
# Success: tt4481414 returned status 200
# Success: tt0441773 returned status 200
# Success: tt14624330 returned status 200
# Success: tt10603396 returned status 200
# Success: tt0756683 returned status 200
# Success: tt1261978 returned status 200
# Success: tt0472043 returned status 200
# Success: tt15333984 returned status 200
# Success: tt8296030 returned status 200
# Success: tt18082758 returned status 200
# Success: tt1270797 returned status 200
# Success: tt0264464 returned status 200
# Success: tt0167261 returned status 200
# Success: tt18393816 returned status 200
# Success: tt14463484 returned status 200
# Success: tt12477480 returned status 200
# Success: tt14895206 returned status 200
# Success: tt3385516 returned status 200
# Success: tt2382320 returned status 200
# Success: tt8936646 returned status 200
# Success: tt21929356 returned status 200
# Success: tt0437086 returned status 200
# Success: tt1217209 returned status 200
# Success: tt1453405 returned status 200
# Success: tt0371746 returned status 200
# Success: tt4913966 returned status 200
# Success: tt1291150 returned status 200
# Success: tt0903624 returned status 200
# Success: tt14128670 returned status 200
# Failed: tt23489208 returned status 404
# Success: tt3420504 returned status 200
# Success: tt1411697 returned status 200
# Success: tt9698480 returned status 200
# Success: tt11671006 returned status 200
# Success: tt1190080 returned status 200
# Success: tt0381707 returned status 200
# Success: tt13024674 returned status 200
# Success: tt2263944 returned status 200
# Success: tt0120082 returned status 200
# Success: tt2179136 returned status 200
# Success: tt3513054 returned status 200
# Success: tt14118246 returned status 200
# Success: tt10327252 returned status 200
# Success: tt5140878 returned status 200
# Success: tt0119643 returned status 200
# Success: tt2103281 returned status 200
# Success: tt5700672 returned status 200
# Success: tt1262416 returned status 200
# Success: tt0111161 returned status 200
# Success: tt1340138 returned status 200
# Success: tt15094426 returned status 200
# Success: tt1825683 returned status 200
# Success: tt2975590 returned status 200
# Success: tt3416532 returned status 200
# Success: tt0145487 returned status 200
# Success: tt3626476 returned status 200
# Success: tt15829632 returned status 200
# Success: tt11399896 returned status 200
# Success: tt0257106 returned status 200
# Success: tt16116174 returned status 200
# Success: tt0118799 returned status 200
# Success: tt12390572 returned status 200
# Success: tt0804555 returned status 200
# Success: tt0448011 returned status 200
# Success: tt8350360 returned status 200
# Success: tt14923260 returned status 200
# Success: tt0133093 returned status 200
# Success: tt0117605 returned status 200
# Success: tt1690953 returned status 200
# Success: tt3513500 returned status 200
# Success: tt2557478 returned status 200
# Success: tt11084896 returned status 200
# Success: tt1778212 returned status 200
# Success: tt0120616 returned status 200
# Success: tt0267913 returned status 200
# Success: tt0369610 returned status 200
# Success: tt4649466 returned status 200
# Success: tt0166813 returned status 200
# Success: tt18245948 returned status 200
# Success: tt7918792 returned status 200
# Success: tt1636826 returned status 200
# Success: tt0120855 returned status 200
# Success: tt0121164 returned status 200
# Success: tt0142236 returned status 200
# Success: tt0351283 returned status 200
# Success: tt1324999 returned status 200
# Success: tt0993840 returned status 200
# Success: tt7339862 returned status 200
# Success: tt1587310 returned status 200
# Success: tt1293847 returned status 200
# Success: tt3606756 returned status 200
# Success: tt18968540 returned status 200
# Success: tt1661199 returned status 200
# Success: tt1772341 returned status 200
# Success: tt0455944 returned status 200
# Success: tt8579674 returned status 200
# Success: tt7978672 returned status 200
# Success: tt21849158 returned status 200
# Success: tt5034870 returned status 200
# Success: tt1951261 returned status 200
# Success: tt13918550 returned status 200
# Success: tt0438097 returned status 200
# Success: tt1675434 returned status 200
# Success: tt13269536 returned status 200
# Success: tt4998632 returned status 200
# Success: tt12749596 returned status 200
# Success: tt1086772 returned status 200
# Success: tt6246322 returned status 200
# Success: tt4881806 returned status 200
# Success: tt0454792 returned status 200
# Success: tt4779682 returned status 200
# Success: tt2866360 returned status 200
# Success: tt12689248 returned status 200
# Success: tt9783600 returned status 200
# Success: tt3371366 returned status 200
# Success: tt14083716 returned status 200
# Success: tt6751668 returned status 200
# Success: tt7126948 returned status 200
# Success: tt7975244 returned status 200
# Success: tt3120408 returned status 200
# Success: tt5790684 returned status 200
# Success: tt12715472 returned status 200
# Success: tt0910970 returned status 200
# Success: tt10431332 returned status 200
# Success: tt11813216 returned status 200
# Success: tt1170358 returned status 200
# Success: tt8784956 returned status 200
# Success: tt0878804 returned status 200
# Success: tt6113488 returned status 200
# Success: tt7339792 returned status 200
# Success: tt6644200 returned status 200
# Success: tt0275847 returned status 200
# Success: tt8006374 returned status 200
# Success: tt5181830 returned status 200
# Failed: tt24172170 returned status 404
# Success: tt0462538 returned status 200
# Success: tt0209163 returned status 200
# Success: tt3704428 returned status 200
# Success: tt4481514 returned status 200
# Success: tt0106950 returned status 200
# Success: tt0065794 returned status 200
# Success: tt1637688 returned status 200
# Success: tt21109538 returned status 200
# Success: tt2446042 returned status 200
# Success: tt0120623 returned status 200
# Success: tt4777008 returned status 200
# Success: tt1502397 returned status 200
# Success: tt1677720 returned status 200
# Success: tt3543918 returned status 200
# Success: tt3107288 returned status 200
# Success: tt12683756 returned status 200
# Success: tt22695198 returned status 200
# Success: tt6164502 returned status 200
# Failed: tt9916720 returned status 404
# Success: tt14292584 returned status 200
# Success: tt1700841 returned status 200
# Success: tt14577304 returned status 200
# Success: tt0137523 returned status 200
# Success: tt0119282 returned status 200
# Success: tt25872924 returned status 200
# Success: tt1038686 returned status 200
# Success: tt6237208 returned status 200
# Success: tt0974015 returned status 200
# Success: tt7504818 returned status 200
# Success: tt1392190 returned status 200
# Success: tt1646971 returned status 200
# Success: tt27940442 returned status 200
# Success: tt1323594 returned status 200
# Success: tt14698534 returned status 200
# Success: tt4332232 returned status 200
# Success: tt5848272 returned status 200
# Success: tt1041829 returned status 200
# Success: tt2231461 returned status 200
# Success: tt11285908 returned status 200
# Success: tt0295700 returned status 200
# Success: tt1014759 returned status 200
# Success: tt14267154 returned status 200
# Success: tt0328880 returned status 200
# Success: tt4614584 returned status 200
# Success: tt1186367 returned status 200
# Success: tt1935859 returned status 200
# Success: tt0892769 returned status 200
# Success: tt0134084 returned status 200
# Success: tt1701223 returned status 200
# Success: tt0876563 returned status 200
# Success: tt6528290 returned status 200
# Success: tt9572006 returned status 200
# Success: tt12616964 returned status 200
# Success: tt0101414 returned status 200
# Success: tt13872380 returned status 200
# Success: tt13580744 returned status 200
# Success: tt1127180 returned status 200
# Success: tt3920820 returned status 200
# Success: tt10198564 returned status 200
# Success: tt2316548 returned status 200
# Success: tt21222434 returned status 200
# Success: tt0172495 returned status 200
# Success: tt13358022 returned status 200
# Success: tt0087538 returned status 200
# Success: tt1259571 returned status 200
# Success: tt1345836 returned status 200
# Success: tt11819890 returned status 200
# Success: tt8550054 returned status 200
# Success: tt13841850 returned status 200
# Success: tt1667889 returned status 200
# Success: tt11755740 returned status 200
# Success: tt0458352 returned status 200
# Success: tt2120120 returned status 200
# Success: tt9426210 returned status 200
# Success: tt1219289 returned status 200
# Success: tt1136617 returned status 200
# Success: tt1564367 returned status 200
# Success: tt8009428 returned status 200
# Success: tt7587604 returned status 200
# Success: tt1302011 returned status 200
# Success: tt0332280 returned status 200
# Success: tt21819250 returned status 200
# Success: tt0829482 returned status 200
# Success: tt10954652 returned status 200
# Success: tt11958344 returned status 200
# Success: tt3470600 returned status 200
# Success: tt2267968 returned status 200
# Success: tt10208198 returned status 200
# Success: tt14369780 returned status 200
# Success: tt2034800 returned status 200
# Success: tt14423802 returned status 200
# Success: tt0103639 returned status 200
# Success: tt5323662 returned status 200
# Success: tt0317705 returned status 200
# Success: tt10731256 returned status 200
# Success: tt3567288 returned status 200
# Success: tt3315342 returned status 200
# Success: tt0199232 returned status 200
# Success: tt0974959 returned status 200
# Success: tt21378968 returned status 200
# Success: tt5726616 returned status 200
# Success: tt5562070 returned status 200
# Success: tt0413300 returned status 200
# Success: tt0790724 returned status 200
# Success: tt6585312 returned status 200
# Success: tt0278665 returned status 200
# Success: tt0101272 returned status 200
# Success: tt22695064 returned status 200
# Success: tt2872732 returned status 200
# Success: tt1436562 returned status 200
# Success: tt0345950 returned status 200
# Success: tt1856101 returned status 200
# Success: tt12573454 returned status 200
# Success: tt3183660 returned status 200
# Success: tt9019352 returned status 200
# Success: tt2582500 returned status 200
# Success: tt10855768 returned status 200
# Success: tt4029412 returned status 200
# Success: tt27441525 returned status 200
# Success: tt16118262 returned status 200
# Success: tt1929263 returned status 200
# Success: tt0315327 returned status 200
# Success: tt12937172 returned status 200
# Success: tt1217213 returned status 200
# Success: tt2375779 returned status 200
# Success: tt1911658 returned status 200
# Success: tt27049583 returned status 200
# Success: tt2404181 returned status 200
# Success: tt0120815 returned status 200
# Success: tt2357291 returned status 200
# Success: tt2268617 returned status 200
# Success: tt0328828 returned status 200
# Success: tt4960748 returned status 200
# Success: tt15296186 returned status 200
# Success: tt13428402 returned status 200
# Success: tt8354218 returned status 200
# Success: tt1407050 returned status 200
# Success: tt1734493 returned status 200
# Success: tt21651560 returned status 200
# Success: tt15720718 returned status 200
# Success: tt11312390 returned status 200
# Success: tt1611224 returned status 200
# Success: tt1679335 returned status 200
# Success: tt1121931 returned status 200
# Success: tt2828996 returned status 200
# Success: tt4972582 returned status 200
# Success: tt1800302 returned status 200
# Success: tt1424381 returned status 200
# Success: tt2184390 returned status 200
# Success: tt6595896 returned status 200
# Success: tt13322120 returned status 200
# Success: tt0099800 returned status 200
# Success: tt26548664 returned status 200
# Success: tt1605630 returned status 200
# Success: tt1823672 returned status 200
# Success: tt1129423 returned status 200
# Success: tt15467380 returned status 200
# Success: tt16303830 returned status 200
# Success: tt7392070 returned status 200
# Success: tt2243537 returned status 200
# Success: tt0361748 returned status 200
# Success: tt1130884 returned status 200
# Success: tt4950110 returned status 200
# Success: tt1396484 returned status 200
# Success: tt15791034 returned status 200
# Success: tt0401729 returned status 200
# Success: tt1524930 returned status 200
# Success: tt2582802 returned status 200
# Success: tt0770828 returned status 200
# Success: tt8080204 returned status 200
# Success: tt11151982 returned status 200
# Success: tt0481499 returned status 200
# Success: tt0398808 returned status 200
# Success: tt0416449 returned status 200
# Success: tt5168832 returned status 200
# Success: tt1877832 returned status 200
# Success: tt12663250 returned status 200
# Success: tt14208870 returned status 200
# Success: tt0448157 returned status 200
# Success: tt3741700 returned status 200
# Success: tt10665338 returned status 200
# Success: tt0184907 returned status 200
# Success: tt15318872 returned status 200
# Success: tt0462499 returned status 200
# Success: tt3416828 returned status 200
# Success: tt0056193 returned status 200
# Success: tt19246408 returned status 200
# Success: tt14309446 returned status 200
# Success: tt0301470 returned status 200
# Success: tt1046173 returned status 200
# Success: tt1318514 returned status 200
# Success: tt9288748 returned status 200
# Success: tt0130623 returned status 200
# Success: tt0938283 returned status 200
# Success: tt3832914 returned status 200
# Success: tt1865567 returned status 200
# Success: tt2066832 returned status 200
# Success: tt9658388 returned status 200
# Success: tt4046784 returned status 200
# Success: tt11304504 returned status 200
# Success: tt1680123 returned status 200
# Success: tt17041964 returned status 200
# Success: tt0856288 returned status 200
# Success: tt0163651 returned status 200
# Success: tt14147224 returned status 200
# Success: tt0213847 returned status 200
# Success: tt9695722 returned status 200
# Success: tt15838850 returned status 200
# Success: tt0822854 returned status 200
# Success: tt0306047 returned status 200
# Success: tt15825238 returned status 200
# Success: tt5220122 returned status 200
# Success: tt0499448 returned status 200
# Success: tt0263488 returned status 200
# Success: tt3174376 returned status 200
# Success: tt0302640 returned status 200
# Success: tt1192628 returned status 200
# Success: tt3322940 returned status 200
# Success: tt2572632 returned status 200
# Success: tt6301452 returned status 200
# Success: tt14199590 returned status 200
# Success: tt0479952 returned status 200
# Success: tt1197624 returned status 200
# Success: tt4788734 returned status 200
# Success: tt1637725 returned status 200
# Success: tt0362120 returned status 200
# Success: tt6723592 returned status 200
# Success: tt4154664 returned status 200
# Success: tt5073620 returned status 200
# Success: tt12676006 returned status 200
# Success: tt15476620 returned status 200
# Success: tt0936501 returned status 200
# Success: tt10515988 returned status 200
# Success: tt14826022 returned status 200
# Success: tt0144084 returned status 200
# Success: tt0259324 returned status 200
# Success: tt20192230 returned status 200
# Success: tt21335908 returned status 200
# Success: tt6133466 returned status 200
# Success: tt4500922 returned status 200
# Success: tt3766354 returned status 200
# Success: tt6054290 returned status 200
# Success: tt14555174 returned status 200
# Success: tt6902332 returned status 200
# Success: tt9784708 returned status 200
# Success: tt1277953 returned status 200
# Success: tt13057626 returned status 200
# Success: tt1206885 returned status 200
# Success: tt17049058 returned status 200
# Success: tt0119807 returned status 200
# Success: tt0387564 returned status 200
# Success: tt8096844 returned status 200
# Success: tt1397280 returned status 200
# Success: tt2316204 returned status 200
# Success: tt0404032 returned status 200
# Success: tt1798684 returned status 200
# Success: tt2231489 returned status 200
# Success: tt13575806 returned status 200
# Success: tt1760980 returned status 200
# Success: tt21078728 returned status 200
# Success: tt4429160 returned status 200
# Success: tt1469304 returned status 200
# Success: tt4273562 returned status 200
# Success: tt8376234 returned status 200
# Success: tt1392170 returned status 200
# Success: tt5052448 returned status 200
# Success: tt0307453 returned status 200
# Success: tt22868844 returned status 200
# Success: tt8119752 returned status 200
# Success: tt10767168 returned status 200
# Success: tt1386697 returned status 200
# Success: tt2679042 returned status 200
# Success: tt4824308 returned status 200
# Success: tt14442328 returned status 200
# Success: tt8356942 returned status 200
# Success: tt19851736 returned status 200
# Success: tt14158554 returned status 200
# Success: tt2131532 returned status 200
# Success: tt2034176 returned status 200
# Success: tt0808146 returned status 200
# Success: tt23144072 returned status 200
# Success: tt2378191 returned status 200
# Success: tt2528814 returned status 200
# Success: tt15389372 returned status 200
# Success: tt1474684 returned status 200
# Success: tt0120382 returned status 200
# Success: tt11286314 returned status 200
# Success: tt3659388 returned status 200
# Success: tt1594562 returned status 200
# Success: tt1723121 returned status 200
# Success: tt3397884 returned status 200
# Success: tt0397892 returned status 200
# Success: tt1392214 returned status 200
# Success: tt0438488 returned status 200
# Success: tt2557490 returned status 200
# Success: tt3717490 returned status 200
# Success: tt3450958 returned status 200
# Success: tt11230050 returned status 200
# Success: tt12532368 returned status 200
# Success: tt15091284 returned status 200
# Success: tt14550642 returned status 200
# Success: tt3486354 returned status 200
# Success: tt17291716 returned status 200
# Success: tt1320253 returned status 200
# Success: tt9203694 returned status 200
# Success: tt0366548 returned status 200
# Success: tt3829266 returned status 200
# Success: tt0120812 returned status 200
# Success: tt1148204 returned status 200
# Success: tt0112642 returned status 200
# Success: tt4244994 returned status 200
# Success: tt0805526 returned status 200
# Success: tt2382009 returned status 200
# Success: tt10023022 returned status 200
# Success: tt4114654 returned status 200
# Success: tt17677744 returned status 200
# Success: tt13265876 returned status 200
# Success: tt9546624 returned status 200
# Success: tt1446192 returned status 200
# Success: tt0803096 returned status 200
# Success: tt0117008 returned status 200
# Success: tt0458339 returned status 200
# Success: tt0167190 returned status 200
# Success: tt0800080 returned status 200
# Success: tt1229238 returned status 200
# Success: tt12444934 returned status 200
# Success: tt8946378 returned status 200
# Success: tt0170016 returned status 200
# Success: tt14837960 returned status 200
# Success: tt8368406 returned status 200
# Success: tt5804314 returned status 200
# Success: tt13603778 returned status 200
# Success: tt15329224 returned status 200
# Success: tt2975578 returned status 200
# Success: tt0266915 returned status 200
# Success: tt0252866 returned status 200
# Success: tt6189022 returned status 200
# Success: tt18394428 returned status 200
# Success: tt0800320 returned status 200
# Success: tt9340892 returned status 200
# Success: tt1477834 returned status 200
# Success: tt1002563 returned status 200
# Success: tt0451279 returned status 200
# Success: tt13698942 returned status 200
# Success: tt0142342 returned status 200
# Success: tt1591095 returned status 200
# Success: tt0293564 returned status 200
# Success: tt13061790 returned status 200
# Success: tt3890160 returned status 200
# Success: tt3731562 returned status 200
# Success: tt3440298 returned status 200
# Success: tt1727776 returned status 200
# Success: tt12057168 returned status 200
# Success: tt1797504 returned status 200
# Success: tt6472976 returned status 200
# Success: tt0806203 returned status 200
# Success: tt0840361 returned status 200
# Success: tt14901058 returned status 200
# Success: tt0332452 returned status 200
# Success: tt0129167 returned status 200
# Success: tt7798634 returned status 200
# Success: tt3774694 returned status 200
# Success: tt0837562 returned status 200
# Success: tt2304662 returned status 200
# Success: tt2567026 returned status 200
# Success: tt13846402 returned status 200
# Success: tt1725929 returned status 200
# Success: tt8022928 returned status 200
# Success: tt1617661 returned status 200
# Success: tt1853728 returned status 200
# Success: tt1253863 returned status 200
# Success: tt0980970 returned status 200
# Success: tt14031960 returned status 200
# Success: tt9362930 returned status 200
# Success: tt0377092 returned status 200
# Success: tt9288822 returned status 200
# Success: tt7236034 returned status 200
# Success: tt5052474 returned status 200
# Success: tt1657507 returned status 200
# Success: tt2521404 returned status 200
# Success: tt4916630 returned status 200
# Success: tt12879624 returned status 200
# Success: tt3717252 returned status 200
# Success: tt8652818 returned status 200
# Success: tt2333784 returned status 200
# Success: tt0116743 returned status 200
# Success: tt14250912 returned status 200
# Success: tt11409820 returned status 200
# Success: tt10944760 returned status 200
# Success: tt9198364 returned status 200
# Success: tt0208298 returned status 200
# Success: tt2175799 returned status 200
# Success: tt1216516 returned status 200
# Success: tt0808151 returned status 200
# Success: tt0313255 returned status 200
# Success: tt15153532 returned status 200
# Success: tt1586752 returned status 200
# Success: tt2132324 returned status 200
# Success: tt23334464 returned status 200
# Success: tt4094724 returned status 200
# Success: tt6442686 returned status 200
# Success: tt8354164 returned status 200
# Success: tt13822738 returned status 200
# Success: tt1980209 returned status 200
# Success: tt1464540 returned status 200
# Success: tt13872248 returned status 200
# Success: tt21860836 returned status 200
# Success: tt11686490 returned status 200
# Success: tt1043427 returned status 200
# Success: tt7914022 returned status 200
# Success: tt11417856 returned status 200
# Success: tt0373051 returned status 200
# Success: tt11687104 returned status 200
# Success: tt6450804 returned status 200
# Success: tt0427954 returned status 200
# Success: tt0857191 returned status 200
# Success: tt1428538 returned status 200
# Success: tt2381249 returned status 200
# Success: tt1259528 returned status 200
# Success: tt17372462 returned status 200
# Success: tt2224026 returned status 200
# Success: tt2279373 returned status 200
# Success: tt2709692 returned status 200
# Success: tt0116126 returned status 200
# Success: tt0113277 returned status 200
# Success: tt12625176 returned status 200
# Success: tt7784604 returned status 200
# Success: tt14134154 returned status 200
# Success: tt26739643 returned status 200
# Success: tt3281548 returned status 200
# Success: tt2283362 returned status 200
# Success: tt16611138 returned status 200
# Success: tt9173154 returned status 200
# Success: tt6823368 returned status 200
# Success: tt0142232 returned status 200
# Success: tt7315746 returned status 200
# Success: tt0151137 returned status 200
# Success: tt2262227 returned status 200
# Success: tt14114802 returned status 200
# Success: tt1956620 returned status 200
# Success: tt2267998 returned status 200
# Success: tt4056738 returned status 200
# Success: tt4503906 returned status 200
# Success: tt7661648 returned status 200
# Success: tt14499632 returned status 200
# Success: tt11112140 returned status 200
# Success: tt2302755 returned status 200
# Success: tt6722802 returned status 200
# Success: tt0119217 returned status 200
# Success: tt15553758 returned status 200
# Success: tt0281358 returned status 200
# Success: tt15131130 returned status 200
# Success: tt1242432 returned status 200
# Success: tt0831387 returned status 200
# Success: tt1071875 returned status 200
# Success: tt14060232 returned status 200
# Success: tt1498569 returned status 200
# Success: tt0114369 returned status 200
# Success: tt1467304 returned status 200
# Success: tt10696784 returned status 200
# Success: tt1496025 returned status 200
# Success: tt4912910 returned status 200
# Success: tt2112281 returned status 200
# Success: tt1001526 returned status 200
# Success: tt0325710 returned status 200
# Success: tt28542200 returned status 200
# Success: tt0398165 returned status 200
# Success: tt14995258 returned status 200
# Success: tt8850222 returned status 200
# Success: tt12193804 returned status 200
# Success: tt1440129 returned status 200
# Success: tt7740496 returned status 200
# Success: tt14174940 returned status 200
# Success: tt4103724 returned status 200
# Success: tt12753120 returned status 200
# Success: tt15789492 returned status 200
# Success: tt1950186 returned status 200
# Success: tt6986990 returned status 200
# Success: tt3040964 returned status 200
# Success: tt1622979 returned status 200
# Success: tt15847872 returned status 200
# Success: tt1632708 returned status 200
# Success: tt10231726 returned status 200
# Success: tt10731768 returned status 200
# Success: tt10600398 returned status 200
# Success: tt10633878 returned status 200
# Success: tt0138749 returned status 200
# Success: tt0405325 returned status 200
# Success: tt10127708 returned status 200
# Success: tt11012066 returned status 200
# Success: tt11209212 returned status 200
# Success: tt0164912 returned status 200
# Success: tt1655441 returned status 200
# Success: tt12908110 returned status 200
# Success: tt3799232 returned status 200
# Success: tt2369135 returned status 200
# Success: tt11041046 returned status 200
# Success: tt0119116 returned status 200
# Success: tt10168670 returned status 200
# Success: tt0367882 returned status 200
# Success: tt11771594 returned status 200
# Success: tt6338498 returned status 200
# Success: tt7947604 returned status 200
# Success: tt3811906 returned status 200
# Success: tt0482629 returned status 200
# Success: tt5623728 returned status 200
# Success: tt2510894 returned status 200
# Success: tt13978306 returned status 200
# Success: tt16491324 returned status 200
# Success: tt0195714 returned status 200
# Success: tt19770238 returned status 200
# Success: tt0120094 returned status 200
# Success: tt3411444 returned status 200
# Success: tt1663202 returned status 200
# Success: tt0286112 returned status 200
# Success: tt13269670 returned status 200
# Success: tt0396171 returned status 200
# Success: tt13064272 returned status 200
# Success: tt0279967 returned status 200
# Success: tt13029044 returned status 200
# Success: tt0470752 returned status 200
# Success: tt1133985 returned status 200
# Success: tt9507234 returned status 200
# Success: tt7601480 returned status 200
# Success: tt5164214 returned status 200
# Success: tt6450186 returned status 200
# Success: tt3569230 returned status 200
# Success: tt2184339 returned status 200
# Success: tt13405778 returned status 200
# Success: tt1295085 returned status 200
# Success: tt0144120 returned status 200
# Success: tt3617996 returned status 200
# Success: tt9742794 returned status 200
# Success: tt0119654 returned status 200
# Success: tt0324216 returned status 200
# Success: tt0120591 returned status 200
# Success: tt3877296 returned status 200
# Success: tt1291584 returned status 200
# Success: tt2015381 returned status 200
# Success: tt0859163 returned status 200
# Success: tt1411250 returned status 200
# Success: tt2404435 returned status 200
# Success: tt1131734 returned status 200
# Success: tt0314353 returned status 200
# Success: tt11365186 returned status 200
# Success: tt10228134 returned status 200
# Success: tt0114148 returned status 200
# Success: tt1028532 returned status 200
# Success: tt4439620 returned status 200
# Success: tt5752192 returned status 200
# Success: tt13655328 returned status 200
# Success: tt3469046 returned status 200
# Success: tt0473075 returned status 200
# Success: tt1530509 returned status 200
# Success: tt0472033 returned status 200
# Success: tt5012504 returned status 200
# Success: tt2543164 returned status 200
# Success: tt1640571 returned status 200
# Success: tt0133240 returned status 200
# Success: tt1670345 returned status 200
# Success: tt5113040 returned status 200
# Success: tt0312528 returned status 200
# Success: tt1727824 returned status 200
# Success: tt8367814 returned status 200
# Success: tt0245674 returned status 200
# Success: tt13539646 returned status 200
# Success: tt10736506 returned status 200
# Success: tt10241772 returned status 200
# Success: tt0338013 returned status 200
# Success: tt0119698 returned status 200
# Success: tt1156398 returned status 200
# ...
# Success: tt0384819 returned status 200
# Success: tt0995829 returned status 200
# Success: tt0445946 returned status 200
# Success: tt10510654 returned status 200
# Success: tt0355702 returned status 200
# Success: tt0310793 returned status 200
# Success: tt4513674 returned status 200
# Success: tt0115988 returned status 200
# Success: tt10545696 returned status 200
# Success: tt2345112 returned status 200
# Success: tt7914416 returned status 200
# Success: tt1742683 returned status 200
# Success: tt13236566 returned status 200
# Success: tt6893370 returned status 200
# Success: tt7137380 returned status 200
# Success: tt1051981 returned status 200
# Success: tt3416536 returned status 200
# Success: tt1047540 returned status 200
# Success: tt3465026 returned status 200
# Success: tt0417217 returned status 200
# Success: tt4577344 returned status 200
# Success: tt1773753 returned status 200
# Success: tt1117581 returned status 200
# Success: tt1450321 returned status 200
# Success: tt0165832 returned status 200
# Success: tt1830577 returned status 200
# Success: tt1077065 returned status 200
# Success: tt0758794 returned status 200
# Success: tt0304669 returned status 200
# Success: tt7095654 returned status 200
# Success: tt14361314 returned status 200
# Success: tt1999995 returned status 200
# Success: tt6536944 returned status 200
# Success: tt9519642 returned status 200
# Success: tt14425000 returned status 200
# Success: tt2396421 returned status 200
# Success: tt0285175 returned status 200
# Success: tt0117887 returned status 200
# Success: tt33336632 returned status 200
# Success: tt5269396 returned status 200
# Success: tt2215285 returned status 200
# Success: tt0128332 returned status 200
# Success: tt6121444 returned status 200
# Success: tt2318527 returned status 200
# Success: tt1646959 returned status 200
# Success: tt11327514 returned status 200
# Success: tt0115472 returned status 200
# Success: tt11188560 returned status 200
# Success: tt0117318 returned status 200
# Success: tt3216348 returned status 200
# Success: tt8372298 returned status 200
# Success: tt1632671 returned status 200
# Success: tt12427158 returned status 200
# Success: tt6904272 returned status 200
# Success: tt1412386 returned status 200
# Success: tt1547234 returned status 200
# Success: tt0139668 returned status 200
# Success: tt10305328 returned status 200
# Success: tt7461200 returned status 200
# Success: tt3606888 returned status 200
# Success: tt1205913 returned status 200
# Success: tt2597804 returned status 200
# Success: tt0351887 returned status 200
# Success: tt0839995 returned status 200
# Success: tt9805504 returned status 200
# Success: tt7456312 returned status 200
# Success: tt7160176 returned status 200
# Success: tt3124476 returned status 200
# Success: tt1537759 returned status 200
# Success: tt1328875 returned status 200
# Success: tt9381682 returned status 200
# Success: tt9471660 returned status 200
# Success: tt0044079 returned status 200
# Success: tt14168394 returned status 200
# Success: tt0407998 returned status 200
# Success: tt0780516 returned status 200
# Success: tt12443220 returned status 200
# Success: tt6479178 returned status 200
# Success: tt2077909 returned status 200
# Success: tt0120901 returned status 200
# Success: tt9109306 returned status 200
# Success: tt0131369 returned status 200
# Success: tt1129445 returned status 200
# Success: tt4827558 returned status 200
# Success: tt0332318 returned status 200
# Success: tt3701644 returned status 200
# Success: tt7035004 returned status 200
# Success: tt3567666 returned status 200
# Success: tt2043865 returned status 200
# Success: tt1878942 returned status 200
# Success: tt8045906 returned status 200
# Success: tt4669788 returned status 200
# Success: tt7983844 returned status 200
# Success: tt6054874 returned status 200
# Success: tt0339135 returned status 200
# Success: tt4964580 returned status 200
# Success: tt10715446 returned status 200
# Success: tt4935334 returned status 200
# Success: tt22208390 returned status 200
# Success: tt0145734 returned status 200
# Success: tt5580146 returned status 200
# Success: tt0119313 returned status 200
# Success: tt6217804 returned status 200
# Success: tt2513074 returned status 200
# Success: tt1133935 returned status 200
# Success: tt0377752 returned status 200
# Success: tt8291806 returned status 200
# Success: tt0113819 returned status 200
# Success: tt1523267 returned status 200
# Success: tt4530832 returned status 200
# Success: tt0271263 returned status 200
# Success: tt0103855 returned status 200
# Success: tt0802948 returned status 200
# Success: tt0199753 returned status 200
# Success: tt0431641 returned status 200
# Success: tt2943178 returned status 200
# Success: tt0302297 returned status 200
# Success: tt0482572 returned status 200
# Success: tt1382725 returned status 200
# Success: tt7386590 returned status 200
# Success: tt0405336 returned status 200
# Success: tt0238112 returned status 200
# Success: tt0338309 returned status 200
# Success: tt0245686 returned status 200
# Success: tt27048129 returned status 200
# Success: tt1984153 returned status 200
# Success: tt1131729 returned status 200
# Success: tt1857596 returned status 200
# Success: tt0112750 returned status 200
# Success: tt5147214 returned status 200
# Success: tt1212419 returned status 200
# Success: tt5929654 returned status 200
# Success: tt0371075 returned status 200
# Success: tt0405296 returned status 200
# Success: tt15384690 returned status 200
# Success: tt5721088 returned status 200
# Success: tt1972571 returned status 200
# Success: tt1785550 returned status 200
# Success: tt5825380 returned status 200
# Success: tt2083379 returned status 200
# Success: tt0269347 returned status 200
# Success: tt21100124 returned status 200
# Success: tt1753968 returned status 200
# Success: tt1196948 returned status 200
# Success: tt0114614 returned status 200
# Success: tt6212478 returned status 200
# Success: tt2126362 returned status 200
# Success: tt1629377 returned status 200
# Success: tt0114681 returned status 200
# Success: tt7608418 returned status 200
# Success: tt0484740 returned status 200
# Success: tt1630626 returned status 200
# Success: tt0294870 returned status 200
# Success: tt0463034 returned status 200
# Success: tt13130024 returned status 200
# Success: tt1519664 returned status 200
# Success: tt8503618 returned status 200
# Success: tt3481634 returned status 200
# Success: tt0303816 returned status 200
# Success: tt7214762 returned status 200
# Success: tt0186654 returned status 200
# Success: tt9242528 returned status 200
# Success: tt1473345 returned status 200
# Success: tt0301526 returned status 200
# Success: tt29573332 returned status 200
# Success: tt2062677 returned status 200
# Success: tt12748300 returned status 200
# Success: tt5840072 returned status 200
# Success: tt1594972 returned status 200
# Success: tt1054487 returned status 200
# Success: tt0263265 returned status 200
# Success: tt6543652 returned status 200
# Success: tt2222052 returned status 200
# Success: tt8266310 returned status 200
# Success: tt12483708 returned status 200
# Success: tt2094018 returned status 200
# Success: tt1389096 returned status 200
# Success: tt1016301 returned status 200
# Success: tt10195614 returned status 200
# Success: tt6564554 returned status 200
# Success: tt1315981 returned status 200
# Success: tt0338216 returned status 200
# Success: tt0840196 returned status 200
# Success: tt0421054 returned status 200
# Success: tt1934452 returned status 200
# Success: tt0433387 returned status 200
# Success: tt0119791 returned status 200
# Success: tt11709244 returned status 200
# Success: tt0389557 returned status 200
# Success: tt1815708 returned status 200
# Success: tt0126886 returned status 200
# Success: tt1582507 returned status 200
# Success: tt0137363 returned status 200
# Success: tt0402399 returned status 200
# Success: tt1078885 returned status 200
# Success: tt10322274 returned status 200
# Success: tt5563334 returned status 200
# Success: tt0365675 returned status 200
# Success: tt8430054 returned status 200
# Success: tt0309377 returned status 200
# Success: tt0119311 returned status 200
# Success: tt4758646 returned status 200
# Success: tt0454919 returned status 200
# Success: tt0332047 returned status 200
# Success: tt6684714 returned status 200
# Success: tt0031936 returned status 200
# Success: tt5096470 returned status 200
# Success: tt0889583 returned status 200
# Success: tt2402603 returned status 200
# Success: tt6142314 returned status 200
# Success: tt0790623 returned status 200
# Success: tt2072227 returned status 200
# Success: tt0180734 returned status 200
# Success: tt2493486 returned status 200
# Success: tt3977462 returned status 200
# Success: tt12599350 returned status 200
# Success: tt0276816 returned status 200
# Success: tt0167049 returned status 200
# Success: tt0025316 returned status 200
# Success: tt13421498 returned status 200
# Success: tt3078242 returned status 200
# Success: tt1439572 returned status 200
# Success: tt10698680 returned status 200
# Success: tt7689966 returned status 200
# Success: tt5153288 returned status 200
# Success: tt7938092 returned status 200
# Success: tt2365580 returned status 200
# Success: tt5301662 returned status 200
# Success: tt0811138 returned status 200
# Success: tt9089294 returned status 200
# Success: tt4385888 returned status 200
# Success: tt0109552 returned status 200
# Success: tt12398350 returned status 200
#                                             title  year rated runtime  \
# 0                                       Creed III  2023    PG     116
# 1                        Avatar: The Way of Water  2022    PG     192
# 2                     The Super Mario Bros. Movie  2023    PG      92
# 3                                         Mummies  2023    PG      88
# 4                                       Supercell  2023    PG     100
# ...                                           ...   ...   ...     ...
# 7095                                The Love Guru  2008    PG      87
# 7096  The Seven Deadly Sins: Prisoners of the Sky  2018    PG      99
# 7097                           20th Century Women  2016     R     119
# 7098             Darkman II: The Return of Durant  1995     R      93
# 7099           The Swan Princess: A Royal Wedding  2020     G      83
#
#                                         genre  \
# 0                        Action, Drama, Sport
# 1                  Action, Adventure, Fantasy
# 2                Animation, Adventure, Comedy
# 3                Animation, Adventure, Comedy
# 4                    Action, Adventure, Drama
# ...                                       ...
# 7095                   Comedy, Romance, Sport
# 7096             Animation, Action, Adventure
# 7097                            Comedy, Drama
# 7098  Action, Crime, Horror, Sci-Fi, Thriller
# 7099             Animation, Adventure, Comedy
#
#                                           director  \
# 0                                Michael B. Jordan
# 1                                    James Cameron
# 2     Aaron Horvath, Michael Jelenic, Pierre Leduc
# 3                        Juan Jesús García Galocha
# 4                        Herbert James Winterstern
# ...                                            ...
# 7095                                Marco Schnabel
# 7096                Yasuto Nishikata, Noriyuki Abe
# 7097                                    Mike Mills
# 7098                                  Bradford May
# 7099                                  Richard Rich
#
#                                                  actors  \
# 0     Michael B. Jordan, Tessa Thompson, Jonathan Ma...
# 1        Sam Worthington, Zoe Saldana, Sigourney Weaver
# 2             Chris Pratt, Anya Taylor-Joy, Charlie Day
# 3         Óscar Barberán, Ana Esther Alborg, Luis Reina
# 4               Skeet Ulrich, Anne Heche, Daniel Diemer
# ...                                                 ...
# 7095             Mike Myers, Jessica Alba, Romany Malco
# 7096               Yûki Kaji, Sora Amamiya, Misaki Kuno
# 7097         Annette Bening, Elle Fanning, Greta Gerwig
# 7098  Larry Drake, Arnold Vosloo, Kim Delaney, Renée...
# 7099        Nina Herzog, Yuri Lowenthal, Joseph Medrano
#
#                                                    plot  \
# 0     Adonis has been thriving in both his career an...
# 1     Jake Sully lives with his newfound family form...
# 2     A plumber named Mario travels through an under...
# 3     It follows three mummies as they end up in pre...
# 4     A teenage boy runs away to follow in the foots...
# ...                                                 ...
# 7095  Pitka, an American raised outside of his count...
# 7096  The Seven Deadly Sins travel to the Sky Temple...
# 7097  In 1979 Santa Barbara, Dorothea is a determine...
# 7098  Darkman and Durant return and they hate each o...
# 7099  Princess Odette and Prince Derek are going to ...
#
#                                      country  \
# 0                              United States
# 1                              United States
# 2                       United States, Japan
# 3                       Spain, United States
# 4                              United States
# ...                                      ...
# 7095  United Kingdom, Germany, United States
# 7096                                   Japan
# 7097                           United States
# 7098                             USA, Canada
# 7099                           United States
#
#                                                  awards  ...  imdb_votes  \
# 0                                        28 nominations  ...      95,684
# 1          Won 1 Oscar. 75 wins & 150 nominations total  ...     509,749
# 2                               2 wins & 47 nominations  ...     246,752
# 3                                         3 nominations  ...       9,366
# 4                                 3 wins & 1 nomination  ...       3,251
# ...                                                 ...  ...         ...
# 7095                             5 wins & 8 nominations  ...      55,340
# 7096                                       1 nomination  ...       5,632
# 7097  Nominated for 1 Oscar. 15 wins & 82 nomination...  ...      50,036
# 7098                                                N/A  ...       5,007
# 7099                                                N/A  ...         115
#
#          imdb_id            languages budget_M US_CA_revenue_M  release_date  \
# 0     tt11145118              English     75.0          271.62    2023-03-02
# 1      tt1630029              English    460.0         2316.79    2022-12-15
# 2      tt6718170              English    100.0          724.46    2023-04-05
# 3     tt23177868   Spanish, Castilian     12.3           34.20    2023-01-05
# 4     tt10559102              English     77.0          340.94    2023-03-17
# ...          ...                  ...      ...             ...           ...
# 7095   tt0811138              English     62.0           40.16    2008-07-10
# 7096   tt9089294             Japanese     62.6          706.00    2018-08-18
# 7097   tt4385888              English      7.0            9.35    2016-12-28
# 7098   tt0109552              English    116.0          475.66    1995-07-11
# 7099  tt12398350              English     92.4          539.40    2020-07-20
#
#       wins nominations  aggregated_score  cumulative_worldwide_gross
# 0        0          28               7.0                $276,148,615
# 1       76         150               7.1              $2,320,250,281
# 2        2          47               5.8              $1,361,992,475
# 3        0           3               5.9                 $54,475,970
# 4        3           1               4.4                     $68,749
# ...    ...         ...               ...                         ...
# 7095     5           8               3.1                 $40,877,556
# 7096     0           1               7.0                  $3,914,227
# 7097    15          82               7.8                  $7,214,806
# 7098     0           0               5.1                        None
# 7099     0           0               5.6                        None
#
# [7095 rows x 22 columns]

# %%
# Turn cumulative worldwide gross into $M
df_clean2["cumulative_worldwide_gross"] = df_clean2["cumulative_worldwide_gross"].apply(lambda x : (float((x.split("$")[1]).replace(",", ""))/1000000) if x else x).round(2)

# %%
# Saving the dataframe into a csv
#df_clean2.to_csv("imdb_cleaned.csv", index=False)
